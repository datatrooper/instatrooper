# %%
import random
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt

import cufflinks as cf
from iso3166 import countries

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go

import pycountry

sns.set_context("talk")
plt.style.use('ggplot')
mpl.rcParams['axes.labelpad']='20'

# %% [markdown]
# ### data en https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/HTTWYL

# %%
df = pd.read_csv("../datos/protests.tab", sep='\t')
df = df[df["protest"] ==1.0]
df["ccode"] = df["ccode"].astype("int32")
df = df[df["country"] == "Colombia"]

columnas = ["year", "protesterviolence", 'location',
       'participants', 'protesteridentity', 'protesterdemand1', 'stateresponse1']
df = df.loc[:,columnas]
df.head(50)
# Out:
#       year  protesterviolence  \
# 998   1990                0.0
# 999   1990                0.0
# 1000  1990                0.0
# 1001  1990                0.0
# 1002  1990                0.0
# 1003  1990                0.0
# 1004  1991                0.0
# 1005  1991                0.0
# 1006  1991                0.0
# 1007  1991                0.0
# 1008  1991                0.0
# 1009  1992                0.0
# 1010  1992                0.0
# 1011  1992                0.0
# 1012  1992                0.0
# 1013  1992                0.0
# 1014  1993                0.0
# 1015  1993                0.0
# 1016  1993                0.0
# 1017  1993                0.0
# 1018  1993                0.0
# 1019  1993                0.0
# 1020  1994                0.0
# 1021  1994                0.0
# 1022  1994                0.0
# 1023  1994                0.0
# 1024  1994                0.0
# 1025  1995                0.0
# 1026  1995                0.0
# 1027  1996                0.0
# 1028  1996                0.0
# 1029  1996                0.0
# 1030  1996                0.0
# 1031  1997                0.0
# 1032  1997                0.0
# 1033  1997                1.0
# 1034  1997                0.0
# 1035  1997                0.0
# 1036  1997                0.0
# 1037  1997                0.0
# 1038  1997                0.0
# 1039  1997                0.0
# 1040  1997                0.0
# 1041  1997                0.0
# 1042  1997                1.0
# 1043  1998                0.0
# 1044  1998                0.0
# 1045  1998                0.0
# 1046  1998                0.0
# 1047  1998                0.0
#
#                                                location participants  \
# 998                                           cartagena         5000
# 999                                      national level         1000
# 1000                                           medellin         3000
# 1001                                             bogota        15000
# 1002                                     national level        14000
# 1003  national level  strike  and Bogota  demonstrat...        10000
# 1004                                     national level       200000
# 1005                              southwestern Colombia        30000
# 1006                                     national level        30000
# 1007                                     national level       400000
# 1008                                     national level        30000
# 1009                                             Bogota           50
# 1010                                    downtown Bogota           50
# 1011                                     national level        14000
# 1012                                          antioquia           50
# 1013                           the Pan American Highway           50
# 1014                                     national level         1000
# 1015          Apartado, Chigorodo, Carepa and Riogrande        25000
# 1016                                     national level       240000
# 1017   the Plaza de Bolivar opposite Congress in Bogota        50000
# 1018                                 around the country         1000
# 1019                                             Bogota          100
# 1020                                    Barrancabermeja         5000
# 1021                                     national level         1100
# 1022               the airport of san jose del guaviare         3000
# 1023                              San Jose del Guaviare         1000
# 1024                                 southern Colombia          5000
# 1025                                     national level         1000
# 1026                      Barrancabermeja and Cartagena         4500
# 1027                             Bogota and Puerto Asis        75000
# 1028                                     national level       250000
# 1029                                     national level       500000
# 1030                                     national level         5000
# 1031                                             Bogota          100
# 1032                                     national level       300000
# 1033                prison in Valledupar; Girardot jail         1200
# 1034                                     national level       120000
# 1035  El Bosque    EHL BOHZ kay    prison, Picalena ...         1000
# 1036                                     national level           50
# 1037                                     national level         2000
# 1038                                     national level        50000
# 1039                                     national level         8000
# 1040                                     national level        13800
# 1041                                     national level        40000
# 1042                           La Picota jail in Bogota          100
# 1043             San Isidro Jail in the city of Popayan         1100
# 1044                                     national level         1000
# 1045                                     national level       600000
# 1046                                     national level       800000
# 1047                                          Chinchina           50
#
#                                       protesteridentity  \
# 998                                             workers
# 999                                workers and students
# 1000                                          Catholics
# 1001  employees of telecommunications company  telec...
# 1002                                     banana workers
# 1003                                            workers
# 1004                                           teachers
# 1005                                       farm workers
# 1006                                    court employees
# 1007                                      state workers
# 1008                                    court employees
# 1009            Residents of the Villa del Prado region
# 1010  Workers of the telephone, energy and water ent...
# 1011                                  telephone workers
# 1012                                      secret judges
# 1013                               Indians and peasants
# 1014                               workers and teachers
# 1015                                     banana workers
# 1016                                           teachers
# 1017                                           teachers
# 1018                                            workers
# 1019    Inhabitants of Bogota s Ciudad Bolivar district
# 1020                                        oil workers
# 1021                                             pilots
# 1022                                            farmers
# 1023                                          peasants
# 1024                          putumayo peasant movement
# 1025         coffee growers and small plantation owners
# 1026                                        oil workers
# 1027                                       coca growers
# 1028                                           teachers
# 1029                            public sector employees
# 1030                                        oil workers
# 1031                             Bogota traffic police
# 1032                                      state workers
# 1033                                          prisoners
# 1034       unionized nurses, doctors and administrators
# 1035                                          prisoners
# 1036                            judicial sector workers
# 1037                                       dock workers
# 1038                   teachers and health care workers
# 1039                                      phone workers
# 1040      Transport workers, oil workers, phone workers
# 1041                                   judicial workers
# 1042                            Prisoners and relatives
# 1043                                          Prsioners
# 1044                                      truck drivers
# 1045                                    state employees
# 1046                              public sector workers
# 1047                                        Colombians
#
#                  protesterdemand1   stateresponse1
# 998   political behavior, process           ignore
# 999   political behavior, process  crowd dispersal
# 1000  political behavior, process           ignore
# 1001  political behavior, process           ignore
# 1002  political behavior, process           ignore
# 1003  price increases, tax policy           ignore
# 1004             police brutality     accomodation
# 1005  political behavior, process           ignore
# 1006  political behavior, process           ignore
# 1007  political behavior, process           ignore
# 1008  political behavior, process           ignore
# 1009  political behavior, process           ignore
# 1010  political behavior, process           ignore
# 1011  political behavior, process     accomodation
# 1012  political behavior, process           ignore
# 1013  political behavior, process  crowd dispersal
# 1014  political behavior, process           ignore
# 1015  political behavior, process           ignore
# 1016  political behavior, process           ignore
# 1017  political behavior, process           ignore
# 1018  political behavior, process           ignore
# 1019  political behavior, process  crowd dispersal
# 1020  political behavior, process           ignore
# 1021  political behavior, process           ignore
# 1022  political behavior, process     accomodation
# 1023  political behavior, process           ignore
# 1024  political behavior, process     accomodation
# 1025           labor wage dispute           ignore
# 1026  political behavior, process           ignore
# 1027  political behavior, process         killings
# 1028  political behavior, process           ignore
# 1029           labor wage dispute           ignore
# 1030             police brutality           ignore
# 1031  political behavior, process           ignore
# 1032           labor wage dispute           ignore
# 1033  political behavior, process  crowd dispersal
# 1034           labor wage dispute           ignore
# 1035  political behavior, process         killings
# 1036           labor wage dispute           ignore
# 1037  price increases, tax policy           ignore
# 1038  political behavior, process           ignore
# 1039  political behavior, process           ignore
# 1040  political behavior, process           ignore
# 1041           labor wage dispute           ignore
# 1042  political behavior, process           ignore
# 1043  political behavior, process     accomodation
# 1044           labor wage dispute           ignore
# 1045  political behavior, process           ignore
# 1046  political behavior, process     accomodation
# 1047  political behavior, process         killings

# %%
df.shape
# Out:
# (133, 7)

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(y="protesterdemand1", data=df, orient="h", palette="pastel")
ax.set_xlabel("Cuenta",fontsize=30)
ax.set_ylabel("Razón",fontsize=30)
ax.set_title("Razones para marchar",fontsize=50)
# Out:
# Text(0.5, 1.0, 'Razones para marchar')

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(y="stateresponse1", data=df, orient="h", palette="pastel")
ax.set_xlabel("Cuenta",fontsize=30)
ax.set_ylabel("Respuesta del Estado",fontsize=30)
ax.set_title("Respuestas del Estado frente a la marcha",fontsize=50)
# Out:
# Text(0.5, 1.0, 'Respuestas del Estado frente a la marcha')

# %%
def si_no(row):
    if row["protesterviolence"] == 1:
        row["protesterviolence"] = "Si"
    else:
        row["protesterviolence"] = "No"
    return row

# %%
df_si_no = df.copy()
df_si_no = df_si_no.apply(si_no, axis=1)
df_si_no.head(50)
sums = df_si_no.protesterviolence.groupby(df_si_no.protesterviolence).count()

# %%
sums
# Out:
# protesterviolence
# No    122
# Si     11
# Name: protesterviolence, dtype: int64

# %%
import plotly.graph_objects as go

labels = sums.index
values = [91.7,8.3]

fig = go.Figure(data=[go.Pie(labels=labels, values=values)])

fig.update_layout(
    title="Violencia por parte de los protestantes",
    font=dict(
        family="Courier New, monospace",
        size=25,
        color="#7f7f7f"
    )
)
fig.show()
# Out:
# <div>
#
#
#             <div id="f68dbfc4-58b9-4a56-a0a8-ca8859a085b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f68dbfc4-58b9-4a56-a0a8-ca8859a085b5")) {
#                     Plotly.newPlot(
#                         'f68dbfc4-58b9-4a56-a0a8-ca8859a085b5',
#                         [{"labels": ["No", "Si"], "type": "pie", "values": [91.7, 8.3]}],
#                         {"font": {"color": "#7f7f7f", "family": "Courier New, monospace", "size": 25}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": " ...

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(x="year", data=df, palette="muted")
ax.set_xlabel("Año",fontsize=30)
ax.set_ylabel("Cuenta",fontsize=30)
ax.set_title("Número de marchas por año",fontsize=50)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, '1990'),
#  Text(0, 0, '1991'),
#  Text(0, 0, '1992'),
#  Text(0, 0, '1993'),
#  Text(0, 0, '1994'),
#  Text(0, 0, '1995'),
#  Text(0, 0, '1996'),
#  Text(0, 0, '1997'),
#  Text(0, 0, '1998'),
#  Text(0, 0, '1999'),
#  Text(0, 0, '2000'),
#  Text(0, 0, '2001'),
#  Text(0, 0, '2002'),
#  Text(0, 0, '2003'),
#  Text(0, 0, '2004'),
#  Text(0, 0, '2005'),
#  Text(0, 0, '2006'),
#  Text(0, 0, '2007'),
#  Text(0, 0, '2008'),
#  Text(0, 0, '2009'),
#  Text(0, 0, '2010'),
#  Text(0, 0, '2011'),
#  Text(0, 0, '2012'),
#  Text(0, 0, '2013'),
#  Text(0, 0, '2014'),
#  Text(0, 0, '2016'),
#  Text(0, 0, '2017'),
#  Text(0, 0, '2018')]

# %%
import collections
from stop_words import get_stop_words
from wordcloud import WordCloud
stopwords = get_stop_words('en')

# %%
all_text = ""
for i, protest in df.iterrows():
    all_text += str(protest["protesteridentity"]) + " "

wordcount = collections.defaultdict(int)
for word in all_text.lower().split():

    if word not in stopwords:
        wordcount[word] += 1

wordcount
# Out:
# defaultdict(int,
#             {'workers': 44,
#              'students': 7,
#              'catholics': 1,
#              'employees': 6,
#              'telecommunications': 1,
#              'company': 2,
#              'telecom': 1,
#              'banana': 2,
#              'teachers': 13,
#              'farm': 1,
#              'court': 2,
#              'state': 8,
#              'residents': 4,
#              'villa': 1,
#              'del': 1,
#              'prado': 1,
#              'region': 1,
#              'telephone,': 1,
#              'energy': 1,
#              'water': 1,
#              'enterprises,': 1,
#              'civil': 2,
#              'registry': 1,
#              'office': 1,
#              'bank': 1,
#              'telephone': 1,
#              'secret': 1,
#              'judges': 1,
#              'indians': 9,
#              'peasants': 9,
#              'inhabitants': 1,
#              'bogota': 2,
#              's': 1,
#              'ciudad': 1,
#              'bolivar': 1,
#              'district': 1,
#              'oil': 9,
#              'pilots': 1,
#              'farmers': 8,
#              'putumayo': 1,
#              'peasant': 2,
#              'movement': 1,
#              'coffee': 3,
#              'growers': 4,
#              'small': 1,
#              'plantation': 1,
#              'owners': 1,
#              'coca': 3,
#              'public': 5,
#              'sector': 3,
#              'traffic': 1,
#              'police': 1,
#              'prisoners': 3,
#              'unionized': 1,
#              'nurses,': 1,
#              'doctors': 1,
#              'administrators': 1,
#              'judicial': 3,
#              'dock': 1,
#              'health': 2,
#              'care': 2,
#              'phone': 2,
#              'transport': 3,
#              'workers,': 5,
#              'relatives': 2,
#              'prsioners': 1,
#              'truck': 1,
#              'drivers': 4,
#              'colombians': 6,
#              'servants': 1,
#              'urban': 1,
#              'bus': 1,
#              'taxi': 2,
#              'leaf': 1,
#              'transportation': 1,
#              'women': 2,
#              'general': 1,
#              'poor': 1,
#              'unemployed': 2,
#              'ecopetrol': 1,
#              'owned': 1,
#              'school': 2,
#              'students,': 1,
#              'unions': 1,
#              'indigenous': 5,
#              'farmers,': 2,
#              'opposition': 2,
#              'lawmakers,': 1,
#              'government': 1,
#              'trade': 1,
#              'union': 1,
#              'television': 1,
#              'actors,': 1,
#              'screenwriters': 1,
#              'set': 1,
#              'designers': 1,
#              'town': 1,
#              'sibate': 1,
#              'members': 1,
#              'tribes': 2,
#              'inmates': 1,
#              'self': 1,
#              'employed': 1,
#              'people,': 2,
#              'citizens': 1,
#              'high': 1,
#              'truckers,': 1,
#              'gasoline': 1,
#              'sellers,': 1,
#              'traders': 1,
#              'local': 2,
#              'norte': 1,
#              'de': 1,
#              'santander': 1,
#              'merchants,': 1,
#              'unions,': 1,
#              'groups': 1,
#              'rural': 1,
#              'laborers': 2,
#              'people': 1,
#              'former': 1,
#              'combatants': 1,
#              'truckers': 2,
#              'motorcyclists': 2,
#              'cyclists': 1,
#              'paez': 1,
#              'demonstrators': 1,
#              'nasa': 1,
#              'tribe': 1,
#              'growing': 1,
#              'growers,': 1,
#              'university': 1,
#              'nan': 2,
#              'peace': 1,
#              'activists': 1,
#              'anti': 1,
#              'bullfighting': 1})

# %%
def colombia_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    red ="hsl(0, 100%, 50%)"
    blue = "hsl(245, 100%, 50%)"
    yellow = "hsl(58, 71%, 50%)"
    colors = [yellow, blue, red]
    return random.choice(colors)

# %%
wc = WordCloud(background_color="white",width=1500, height=1000).generate_from_frequencies(wordcount)

# %%
fig = plt.figure(figsize=(15,10))
plt.imshow(wc.recolor(color_func=colombia_color_func, random_state=3), interpolation="bilinear")
plt.title("Mayores participantes", fontsize=38)
plt.axis("off")
plt.show()

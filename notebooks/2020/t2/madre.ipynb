# %%
import pandas as pd
import seaborn as sns
from textblob import TextBlob
from wordcloud import WordCloud
from stop_words import get_stop_words
from collections import Counter
import matplotlib.pyplot as plt
import nltk
import re
import numpy as np

from PIL import Image

plt.style.use('https://raw.githubusercontent.com/datatrooper/instatrooper/master/styles/whitetrooper.mplstyle')
dp = [
    "#e6d3ad",
    "#967B4F",
    "#46493D",
    "#839DA5",
    "#9FADAD",
    "#2B4144",
    "#986E37"
]

# %%
df = pd.read_csv("../../../data/madre.csv", names=["words"])

# %%
df["words"] = df["words"].str.lower()

# %%
words = df["words"].str.cat(sep=' ').lower().split(" ")
word_count = Counter(words)

# %%
word_count
# Out:
# Counter({'inspiracion': 3,
#          'magia': 3,
#          'comprensiva': 5,
#          'fuerte': 7,
#          'talentosa': 4,
#          'berraca': 3,
#          'dulce': 4,
#          'hermosa': 3,
#          'cariño': 3,
#          'amor': 6,
#          'perfecta': 3,
#          'magnifica': 3,
#          'energética': 1,
#          'independiente': 1,
#          'fabulosa': 1,
#          'real': 1,
#          'triunfadora': 1,
#          'honesta': 1,
#          'feliz': 1,
#          'inteligente': 1,
#          'suficiente': 1,
#          'positiva': 1,
#          'segura': 1,
#          'soñadora': 1,
#          'apasionada': 1,
#          'directa': 1,
#          'graciosa': 1,
#          'interesante': 1,
#          'valiosa': 1,
#          'ambiciosa': 1,
#          'enfocada': 1,
#          'aventurera': 1,
#          'brillante': 1,
#          'recursiva': 1,
#          'dedicada': 1,
#          'confiable': 1,
#          'habilidosa': 1,
#          'decidida': 1,
# ...

# %%
0.239*255
# Out:
# 60.945

# %%
def white_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    return "rgb(28,28,60)"

# %%
corazon = np.array(Image.open("corazon.png"))

# %%
wc = WordCloud(background_color="rgba(255, 255, 255, 0)", mode="RGBA",
               width=1000, 
               height=1500,
               mask=corazon).generate_from_frequencies(word_count)
wc.recolor(color_func=white_color_func, random_state=336)

fig = plt.figure(figsize=(20,15))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.savefig(f'madre.png',bbox_inches='tight', transparent="True", pad_inches = 0)
plt.show()

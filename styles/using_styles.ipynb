# %%
# import pandas as pd
# import matplotlib as mpl
# import seaborn as sns
# import matplotlib.pyplot as plt
# sns.reset_defaults()

# datatrooper_palette = [
#     "#E6D3AD",
#     "#967B4F",
#     "#46493D",
#     "#839DA5",
#     "#9FADAD",
#     "#2B4144",
#     "#986E37"
# ]

# plt.style.use('example')
# sns.set_palette(datatrooper_palette)
# #  #1D1D3D o black
# sns.set(rc={'axes.facecolor':'black', 'figure.facecolor':'black'})

# sns.set_context("talk")
# COLOR = 'white'
# mpl.rcParams['text.color'] = COLOR
# mpl.rcParams['axes.labelcolor'] = COLOR
# mpl.rcParams['xtick.color'] = COLOR
# mpl.rcParams['ytick.color'] = COLOR

# %%
import pandas as pd
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
sns.reset_defaults()

plt.style.use('https://raw.githubusercontent.com/datatrooper/instatrooper/master/styles/bluetrooper.mplstyle')
# Out:
# Illegal line #22
# 	"    "E6D3AD",
# "
# 	in file "https://raw.githubusercontent.com/datatrooper/instatrooper/master/styles/bluetrooper.mplstyle"
# Illegal line #23
# 	"    "967B4F",
# "
# 	in file "https://raw.githubusercontent.com/datatrooper/instatrooper/master/styles/bluetrooper.mplstyle"
# Illegal line #24
# 	"    "46493D",
# "
# 	in file "https://raw.githubusercontent.com/datatrooper/instatrooper/master/styles/bluetrooper.mplstyle"
# Illegal line #25
# 	"    "839DA5",
# "
# 	in file "https://raw.githubusercontent.com/datatrooper/instatrooper/master/styles/bluetrooper.mplstyle"
# Illegal line #26
# 	"    "9FADAD",
# "
# 	in file "https://raw.githubusercontent.com/datatrooper/instatrooper/master/styles/bluetrooper.mplstyle"
# Illegal line #27
# 	"    "2B4144",
# "
# 	in file "https://raw.githubusercontent.com/datatrooper/instatrooper/master/styles/bluetrooper.mplstyle"
# Illegal line #28
# 	"    "986E37"]) #hex colours
# "
# 	in file "https://raw.githubusercontent.com/datatrooper/instatrooper/master/styles/bluetrooper.mplstyle"
# Bad val "'white'" on line #1
# 	"text.color : 'white'
# "
# 	in file "https://raw.githubusercontent.com/datatrooper/instatrooper/master/styles/bluetrooper.mplstyle"
# 	Key text.color: 'white' does not look like a color arg
# Bad val "'white'" on line #6
# 	"axes.edgecolor : 'white'
# "
# 	in file "https://raw.githubusercontent.com/datatrooper/instatrooper/master/styles/bluetrooper.mplstyle"
# 	Key axes.edgecolor: 'white' does not look like a color arg
# Bad val "'white'" on line #7
# 	"axes.labelcolor : 'white'
# "
# 	in file "https://raw.githubusercontent.com/datatrooper/instatrooper/master/styles/bluetrooper.mplstyle"
# 	Key axes.labelcolor: 'white' does not look like a color arg
# Bad val "cycler('color', [" on line #21
# 	"axes.prop_cycle : cycler('color', [
# "
# 	in file "https://raw.githubusercontent.com/datatrooper/instatrooper/master/styles/bluetrooper.mplstyle"
# 	Key axes.prop_cycle: 'cycler('color', [' is not a valid cycler construction: unexpected EOF while parsing (<string>, line 1)

# %%
tips = sns.load_dataset("tips")
ax = sns.barplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
fmri = sns.load_dataset("fmri")
ax = sns.lineplot(x="timepoint", y="signal", data=fmri)
plt.show()
